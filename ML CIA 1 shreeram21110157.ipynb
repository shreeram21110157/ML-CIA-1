# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
np.random.seed(69)
x = np.random.uniform(2,8,1000)
y = np.random.uniform(4,10,1000)

# %%
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ## Simple Linear Regrssion

# %%
xmean = x.mean()
ymean = y.mean()

# %%
num,den = 0,0
for i in range(1000):
    num += (x[i]-xmean)*(y[i]-ymean)
    den += (x[i]-xmean)**2
m = num/den
m
# Out:
# -0.009004477696779997

# %%
c = ymean - (m*xmean)
c
# Out:
# 7.019710217674836

# %%
Y1 = m*x + c 
plt.scatter(x,y)
plt.plot(x,Y1,c = 'r')

# %% [markdown]
# ## Using Gradient Descent

# %%
learning_rate = 0.00001
m1,c1 = 0,0
for i in range(500):
    Y2 = (m1*x)+c1
    der_m = (-2)*(sum(x*(y-Y2)))
    der_c = (-2)*(sum(y-Y2))
    
    m1 = m1-(learning_rate*der_m)
    c1 = c1-(learning_rate*der_c)

# %%
Y3 = (m1*x) + c1
plt.scatter(x,y)
plt.plot(x,Y3,c='r')
plt.plot()
# Out:
# []

# %% [markdown]
# ## Using sklearn

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25)

# %%
from sklearn.linear_model import LinearRegression
lreg = LinearRegression()

x_train = x_train.reshape(-1,1)
y_train = y_train.reshape(-1,1)
x_test = x_test.reshape(-1,1)
y_test = y_test.reshape(-1,1)

lreg.fit(x_train,y_train)
Y4 = lreg.predict(x_test)

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test,Y4,c='r')
plt.show()

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
  
mae = mean_absolute_error(y_true=y_test,y_pred=Y4)

mse = mean_squared_error(y_true=y_test,y_pred=Y4) 
rmse = mean_squared_error(y_true=y_test,y_pred=Y4,squared=False)
  
print("MAE:",mae)
print("MSE:",mse)
print("RMSE:",rmse)
# Out:
# MAE: 1.5184447443019475
# MSE: 3.045328149422001
# RMSE: 1.7450868601367673

# %%
m2 = lreg.coef_

# %%
c2 = lreg.intercept_

# %%
M = [m,m1,m2[0][0]]
C = [c,c1,c2[0]]
df = pd.DataFrame([M,C],columns=['Simple LR','Using GD','Using Sklearn'],index=['Slope','Intercept'])
df
# Out:
#            Simple LR  Using GD  Using Sklearn
# Slope      -0.009004  0.433103       0.003638
# Intercept   7.019710  4.575916       6.980457
